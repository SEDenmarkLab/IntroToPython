# %% [markdown]
# ## Exercise 4.1
#
# * Use a lambda function to sort a list of strings with a custom sorting rule
#   * For example, you could do something like organize a list alphabetically based on the 2nd letter of their name.
#   * This function should be able to handle a list like this:
#     * ['Matthew', 'Tatsuto', 'Dongchen', 'Tony', 'Blake', 'Elena', 'Shangheng', "Margherita', 'Matt', 'Jim', 'Nick', 'Jacob', 'Roberto', 'Felix', 'Michela', 'Yuki', 'Behrad', 'Sateesh']

# %%
#imports (import anything you need for this question)
from typing import List


def sortBySecondLetter(names: List[str]) -> List[str]: #this is a type hints/annotations examples presented for you, you will be doing this your self in the following question
    pass#delete this line after you finish
    #your code here



#test for you output (do not edit this)
if sortBySecondLetter(['Matthew', 'Tatsuto', 'Dongchen', 'Tony', 'Blake', 'Elena', 'Shangheng', 'Margherita', 'Matt', 'Jim', 'Nick', 'Jacob', 'Roberto', 'Felix', 'Michela', 'Yuki', 'Behrad', 'Sateesh']) == ['Matthew', 'Tatsuto', 'Margherita', 'Matt', 'Jacob', 'Sateesh', 'Felix', 'Behrad', 'Shangheng', 'Jim', 'Nick', 'Michela', 'Blake', 'Elena', 'Dongchen', 'Tony', 'Roberto', 'Yuki']:
    print("Great! You have the correct output. The correct output is ['Matthew', 'Tatsuto', 'Margherita', 'Matt', 'Jacob', 'Sateesh', 'Felix', 'Behrad', 'Shangheng', 'Jim', 'Nick', 'Michela', 'Blake', 'Elena', 'Dongchen', 'Tony', 'Roberto', 'Yuki']")
else:
    print(f"Your output is: {sortBySecondLetter(['Matthew', 'Tatsuto', 'Dongchen', 'Tony', 'Blake', 'Elena', 'Shangheng', 'Margherita', 'Matt', 'Jim', 'Nick', 'Jacob', 'Roberto', 'Felix', 'Michela', 'Yuki', 'Behrad', 'Sateesh'])}, the correct answer is ['Matthew', 'Tatsuto', 'Margherita', 'Matt', 'Jacob', 'Sateesh', 'Felix', 'Behrad', 'Shangheng', 'Jim', 'Nick', 'Michela', 'Blake', 'Elena', 'Dongchen', 'Tony', 'Roberto', 'Yuki'], please try again")


#write a couple more tests yourself to test your code(call your function with some input(s) to see if the output(s) is correct):
# Out:
# Your output is: None, the correct answer is ['Matthew', 'Tatsuto', 'Margherita', 'Matt', 'Jacob', 'Sateesh', 'Felix', 'Behrad', 'Shangheng', 'Jim', 'Nick', 'Michela', 'Blake', 'Elena', 'Dongchen', 'Tony', 'Roberto', 'Yuki'], please try again

# %% [markdown]
# ## Exercise 4.2
#
# * Create a function that converts SI units of distances as a string argument into one of the decimal prefix numbers (i.e. convert it to SI with scientific notation)
#   * This should be able to handle a list such as this:
#     * ['1.4 A', '134 nm', '254 um', '530 mm', '765 cm', '812 m', '299 km']

# %%
#imports (import anything you need for this question)

def convertUnitsToSi(distances):
    pass#delete this line after you finish
    #your code here



#test for you output (do not edit this)
if convertUnitsToSi(['1.4 A', '134 nm', '254 um', '530 mm', '765 cm', '812 m', '299 km']) == ['1.40e-10 m', '1.34e-07 m', '2.54e-04 m', '5.30e-01 m', '7.65e+00 m', '8.12e+02 m', '2.99e+05 m']:
    print("Great! You have the correct output. The correct output is ['1.40e-10 m', '1.34e-07 m', '2.54e-04 m', '5.30e-01 m', '7.65e+00 m', '8.12e+02 m', '2.99e+05 m']")
else:
    print(f"Your output is: {convertUnitsToSi(['1.4 A', '134 nm', '254 um', '530 mm', '765 cm', '812 m', '299 km'])}, the correct answer is ['1.40e-10 m', '1.34e-07 m', '2.54e-04 m', '5.30e-01 m', '7.65e+00 m', '8.12e+02 m', '2.99e+05 m'], please try again")



#write a couple more tests yourself to test your code(call your function with some input(s) to see if the output(s) is correct):
# Out:
# Your output is: None, the correct answer is ['1.40e-10 m', '1.34e-07 m', '2.54e-04 m', '5.30e-01 m', '7.65e+00 m', '8.12e+02 m', '2.99e+05 m'], please try again

# %% [markdown]
# ## Exercise 4.3
#
# * Create a sum function that handles an undefined number of inputs
#   * This should be able to handle `int`, `float`, and complex numbers.

# %%
#imports (import anything you need for this question)


def sumThatSupportInfiniteInputs(*nums):
    pass#delete this line after you finish
    #your code here


#test for you output (do not edit this)
if sumThatSupportInfiniteInputs(10, 2.5, 3.14, 2 + 2j) == 17.64 + 2j:
    print("Great! You have the correct output. The correct output is 17.64 + 2j")
else:
    print(f"Your output is: {sumThatSupportInfiniteInputs(10, 2.5, 3.14, 2 + 2j)}, the correct answer is 17.64 + 2j, please try again")




#write a couple more tests yourself to test your code(call your function with some input(s) to see if the output(s) is correct):

# %% [markdown]
# ## Exercise 4.4
#
# * Create a type-annotated function that computes the distances between two 3D points
#   * All arguments should have type annotations, and you should be able to handle "Euclidean" and "Spherical" coordinates

# %%
#imports (import anything you need for this question)
import math

def calculate3dPointsDistance(point1, point2, Coordinate):
    pass#delete this line after you finish
    #your code here
    



#test for you output (do not edit this)
print("Test 1 (Euclidean):")
if calculate3dPointsDistance((0, 0, 0), (3, 4, 0), 'Euclidean') == 5:
    print("Great! You have the correct output. The correct output is 5")
else:
    print(f"Your output is: {calculate3dPointsDistance((0, 0, 0), (3, 4, 0), 'Euclidean')}, the correct answer is 5, please try again")
print("Test 2 (Spherical):")
try:
    if abs(calculate3dPointsDistance((10, math.pi / 2, 0), (10, math.pi / 2, math.pi / 2), 'Spherical') - 14.142135623730951) < 0.001:
        print("Great! You have the correct output. The correct output is around 14.142135623730951")
    else:
        print(f"Your output is: {calculate3dPointsDistance((10, math.pi / 2, 0), (10, math.pi / 2, math.pi / 2), 'Spherical')}, the correct answer is around 14.142135623730951, please try again")
except TypeError:
    print("if this line appears, you might not have the correct return type of the funtion 'calculate3dPointsDistance', this also happens when you are not finished with the implementation of the function.")



#write a couple more tests yourself to test your code(call your function with some input(s) to see if the output(s) is correct):
#try both Euclidean and Spherical
# Out:
# Test 1 (Euclidean):
# Your output is: None, the correct answer is 5, please try again
# Test 2 (Spherical):
# if this line appears, you might not have the correct return type of the funtion 'calculate3dPointsDistance', this also happens when you are not finished with the implementation of the function.

# %% [markdown]
# ## Exercise 4.5
#
# * Create a function thyat takes a mandatory first and last name, but also an undefined number of keyword arguments (i.e. age, occupation, and location), and returns a dictionary
#   * This should raise errors when unexpected types appear in the dictionary (i.e. `occupation` should not be 2)

# %%
#imports (import anything you need for this question)


def personDictionary(firstName, lastName, **info):
    pass#delete this line after you finish
    #your code here


#test for you output (do not edit this)
if personDictionary("Tony", "He", age=18, occupation="student", location="UIUC") == {'first name': 'Tony', 'last name': 'He', 'age': 18, 'occupation': 'student', 'location': 'UIUC'}:
    print("Great! You have the correct output. The correct output is {'first name': 'Tony', 'last name': 'He', 'age': 18, 'occupation': 'student', 'location': 'UIUC'}")
else:
    print(f"Your output is: {personDictionary("Tony", "He", age=18, occupation="student", location="UIUC")}, the correct answer is {{'first name': 'Tony', 'last name': 'He', 'age': 18, 'occupation': 'student', 'location': 'UIUC'}}, please try again")
try:
    personDictionary("Tony", "He", age=18, occupation=2, location="UIUC")
    print("error not catched, try again")
except TypeError:
    print("Great, the error of ocupation is 2 is catched")




#write a couple more tests yourself to test your code(call your function with some input(s) to see if the output(s) is correct):
#try both regular tests as well as tests for catching errors
# Out:
# Your output is: None, the correct answer is {'first name': 'Tony', 'last name': 'He', 'age': 18, 'occupation': 'student', 'location': 'UIUC'}, please try again
# error not catched, try again
