# %% [markdown]
# ## Exercise 6.1
#
# * Create a function that opens [Tutorial6.csv](./Tutorial6.csv) in native Python and creates an IR (infrared) spectrum directly from the file using matplotlib.
#   * You should do this with both the `csv` module and using read/write operations.
#   * You are not allowed to use `pandas` or `numpy`
#   * Note: The x-axis starts at 4000 and goes down to 500. Also the "-1" should be superscripted on the x-axis

# %%
#imports (import anything you need for this question)


def IRSpectrum():
    pass#delete this line after you finish
    #your code here


#test for you output (do not edit this)
IRSpectrum()

# %% [markdown]
# ## Exercise 6.2
#
# * Do the same thing you did in **Exercise 6.1**, but use `pandas`/`numpy` in combination with `matplotlib`

# %%
#imports (import anything you need for this question)


def IRSpectrumWithPandasNumpy():
    pass#delete this line after you finish
    #your code here


#test for you output (do not edit this)
IRSpectrumWithPandasNumpy()

# %% [markdown]
# ## Exercise 6.3
#
# * Create a violin plot representing the different types of alkenes within the file [SADExample.csv](./SADExample.csv)

# %%
#imports (import anything you need for this question)


def ViolinPlot():
    pass#delete this line after you finish
    #your code here


#test for you output (do not edit this)
ViolinPlot()

# %% [markdown]
# ## Exercise 6.4 (refer back to 3.1)
#
# * After you accomplish exercise 3.1, you are now allowed to download/use `numpy`, and attempt to do what you did in 3.1 within a single line.

# %%
#imports (import anything you need for this question)


def NumpyMedian(lists):
    pass#delete this line after you finish
    #your code here


#test for you output (do not edit this)
if NumpyMedian([10.5, 2, 33, 4, 15]) == 10.5:
    print("Great! You have the correct output. The correct out put is 10.5")
else:
    print(f"Your output is: {NumpyMedian([10.5, 2, 33, 4, 15])}, the correct answer is 10.5, please try again")


#write a couple more tests yourself to test your code(call your function with some input(s) to see if the output(s) is correct):
#for example, test your code with list that contains negative numbers

# %% [markdown]
# ## Exercise 6.5 (refer back to 4.1)
#
# * Once you have done exercise 4.1 with native python, see if you can do something similar using `numpy` leveraging `np.vectorize` and `np.argsort`

# %%
#imports (import anything you need for this question)



def NumpySortBySecondLetter(names):
    pass#delete this line after you finish
    #your code here



#test for you output (do not edit this)
if NumpySortBySecondLetter(['Matthew', 'Tatsuto', 'Dongchen', 'Tony', 'Blake', 'Elena', 'Shangheng', 'Margherita', 'Matt', 'Jim', 'Nick', 'Jacob', 'Roberto', 'Felix', 'Michela', 'Yuki', 'Behrad', 'Sateesh']) == ['Matthew', 'Tatsuto', 'Margherita', 'Matt', 'Jacob', 'Sateesh', 'Felix', 'Behrad', 'Shangheng', 'Jim', 'Nick', 'Michela', 'Blake', 'Elena', 'Dongchen', 'Tony', 'Roberto', 'Yuki']:
    print("Great! You have the correct output. The correct output is ['Matthew', 'Tatsuto', 'Margherita', 'Matt', 'Jacob', 'Sateesh', 'Felix', 'Behrad', 'Shangheng', 'Jim', 'Nick', 'Michela', 'Blake', 'Elena', 'Dongchen', 'Tony', 'Roberto', 'Yuki']")
else:
    print(f"Your output is: {NumpySortBySecondLetter(['Matthew', 'Tatsuto', 'Dongchen', 'Tony', 'Blake', 'Elena', 'Shangheng', 'Margherita', 'Matt', 'Jim', 'Nick', 'Jacob', 'Roberto', 'Felix', 'Michela', 'Yuki', 'Behrad', 'Sateesh'])}, the correct answer is ['Matthew', 'Tatsuto', 'Margherita', 'Matt', 'Jacob', 'Sateesh', 'Felix', 'Behrad', 'Shangheng', 'Jim', 'Nick', 'Michela', 'Blake', 'Elena', 'Dongchen', 'Tony', 'Roberto', 'Yuki'], please try again")


#write a couple more tests yourself to test your code(call your function with some input(s) to see if the output(s) is correct):
